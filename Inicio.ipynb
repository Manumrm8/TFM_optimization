# %% [markdown]
# ## TWO OF

# %%
#!pip install matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Ruta al archivo de texto
ruta_archivo = 'data/kbcl_instances/two_of/A3_7500_150_15.txt'

# Paso 1: Leer la primera línea para obtener n, m, k
with open(ruta_archivo, 'r') as archivo:
    primera_linea = archivo.readline().strip()
    n, m, k = map(int, primera_linea.split())

# %%
df_sitios_a_proveer = pd.read_csv(ruta_archivo, skiprows=1, nrows=n, header=None, delim_whitespace=True)
df_sitios_a_proveer.columns = ['x', 'y']  # Nombrar columnas para facilitar el acceso

# Paso 3: Leer las siguientes m líneas para el segundo dataframe
df_sitios_de_suministro = pd.read_csv(ruta_archivo, skiprows=1+n, nrows=m, header=None, delim_whitespace=True)
df_sitios_de_suministro.columns = ['x', 'y']  # Nombrar columnas para facilitar el acceso
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11472\3334654122.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_sitios_a_proveer = pd.read_csv(ruta_archivo, skiprows=1, nrows=n, header=None, delim_whitespace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_11472\3334654122.py:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_sitios_de_suministro = pd.read_csv(ruta_archivo, skiprows=1+n, nrows=m, header=None, delim_whitespace=True)

# %%
plt.figure(figsize=(10, 8))
plt.scatter(df_sitios_a_proveer['x'], df_sitios_a_proveer['y'], color='green', label='Sitios a Proveer', alpha=0.5)
plt.scatter(df_sitios_de_suministro['x'], df_sitios_de_suministro['y'], color='blue', label='Sitios de Suministro', alpha=0.5)

# Configurar etiquetas y leyenda
plt.xlabel('Posición en X')
plt.ylabel('Posición en Y')
plt.title('Distribución de Sitios a Proveer y de Suministro')
plt.legend()
plt.grid(True)

# Mostrar el gráfico
plt.show()
